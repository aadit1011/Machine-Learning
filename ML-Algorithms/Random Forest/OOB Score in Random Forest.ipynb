# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('voice.csv')
encoder=LabelEncoder()
df['label']=encoder.fit_transform(np.array(df['label']))
df
# Out:
#       meanfreq        sd    median       Q25       Q75  ...    mindom    maxdom   dfrange   modindx  label
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  ...  0.007812  0.007812  0.000000  0.000000      1
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  ...  0.007812  0.054688  0.046875  0.052632      1
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  ...  0.007812  0.015625  0.007812  0.046512      1
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  ...  0.007812  0.562500  0.554688  0.247119      1
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  ...  0.007812  5.484375  5.476562  0.208274      1
# ...        ...       ...       ...       ...       ...  ...       ...       ...       ...       ...    ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  ...  0.007812  4.210938  4.203125  0.161929      0
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  ...  0.039062  3.679688  3.640625  0.277897      0
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=['label']),df['label'],random_state=42,shuffle=True,train_size=0.85)

# %%
x_train
# Out:
#       meanfreq        sd    median       Q25       Q75  ...   meandom    mindom    maxdom   dfrange   modindx
# 598   0.169668  0.054224  0.183928  0.122197  0.217216  ...  0.239763  0.007812  0.890625  0.882812  0.212062
# 3136  0.132017  0.084652  0.130812  0.048031  0.210136  ...  0.751302  0.007812  6.195312  6.187500  0.182645
# 73    0.200830  0.053066  0.210059  0.185332  0.236198  ...  1.067057  0.070312  5.593750  5.523438  0.336376
# 2971  0.164624  0.050922  0.163169  0.146888  0.189112  ...  0.806387  0.146484  3.579102  3.432617  0.379527
# 48    0.158657  0.067564  0.161062  0.104452  0.219197  ...  0.467797  0.007812  6.882812  6.875000  0.090938
# ...        ...       ...       ...       ...       ...  ...       ...       ...       ...       ...       ...
# 3092  0.166738  0.052677  0.169427  0.162650  0.189223  ...  0.174154  0.161133  0.214844  0.053711  0.136364
# ...

# %%
x_test
# Out:
#       meanfreq        sd    median       Q25       Q75  ...   meandom    mindom     maxdom    dfrange   modindx
# 2148  0.186833  0.027472  0.184325  0.173955  0.204731  ...  0.178571  0.007812   0.226562   0.218750  0.108929
# 1124  0.188879  0.060316  0.195537  0.138072  0.242975  ...  0.855938  0.023438   8.718750   8.695312  0.098712
# 170   0.150705  0.087127  0.174299  0.069666  0.226082  ...  1.240954  0.007812   5.562500   5.554688  0.332396
# 3158  0.183667  0.040607  0.182534  0.156480  0.207646  ...  0.550312  0.007812   3.421875   3.414062  0.166503
# 2229  0.205159  0.039543  0.210805  0.186667  0.228908  ...  1.578835  0.187500  10.804688  10.617188  0.113644
# ...        ...       ...       ...       ...       ...  ...       ...       ...        ...        ...       ...
# 2423  0.219964  0.040546  0.220187  0.194766  0.250467  ...  1.873958  0.023438   7.921875   7.898438  0.146060
# ...

# %%
y_train
# Out:
# 598     1
# 3136    0
# 73      1
# 2971    0
# 48      1
#        ..
# 3092    0
# 1095    1
# 1130    1
# 1294    1
# 860     1
# Name: label, Length: 2692, dtype: int64

# %%
y_test
# Out:
# 2148    0
# 1124    1
# 170     1
# 3158    0
# 2229    0
#        ..
# 2423    0
# 1200    1
# 511     1
# 746     1
# 1593    0
# Name: label, Length: 476, dtype: int64

# %%
rf=RandomForestClassifier(n_estimators=500,verbose=True,n_jobs=-1,oob_score=True)

# %%
rf.fit(x_train,y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:    2.7s finished
# RandomForestClassifier(n_estimators=500, n_jobs=-1, oob_score=True,
#                        verbose=True)

# %%
rf.oob_score_
# Out:
# 0.9806835066864784
