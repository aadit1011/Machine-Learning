# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('laptopData.csv')
df.sample(10)
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 755        755.0  Lenovo  2 in 1 Convertible   13.3
# 975        975.0      HP            Notebook   15.6
# 596        596.0  Lenovo  2 in 1 Convertible   13.3
# 120        120.0    Acer            Notebook   15.6
# 1035      1035.0      HP           Ultrabook   12.5
# 1287      1287.0      HP            Notebook   15.6
# 747          NaN     NaN                 NaN    NaN
# 67          67.0      HP            Notebook     14
# 123        123.0      HP            Notebook   17.3
# 1144      1144.0      HP  2 in 1 Convertible   13.3
#
#                                 ScreenResolution  \
# 755   IPS Panel Quad HD+ / Touchscreen 3200x1800
# 975                  IPS Panel Full HD 1920x1080
# 596    IPS Panel Full HD / Touchscreen 1920x1080
# 120    IPS Panel Full HD / Touchscreen 1920x1080
# 1035                           Full HD 1920x1080
# 1287                                    1366x768
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1273 non-null   object
#  3   Inches            1273 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1273 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1273 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %% [markdown]
# Handling Null Values

# %%
df.isna().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
null=df.isna().sum()
total=df.shape[0]
per=(null/total)*100
per
# Out:
# Unnamed: 0          2.302379
# Company             2.302379
# TypeName            2.302379
# Inches              2.302379
# ScreenResolution    2.302379
# Cpu                 2.302379
# Ram                 2.302379
# Memory              2.302379
# Gpu                 2.302379
# OpSys               2.302379
# Weight              2.302379
# Price               2.302379
# dtype: float64

# %% [markdown]
# Calculating the Percentage of NUll Value in the Dataset

# %%
(df.isna().sum().sum()/(df.shape[0]*df.shape[1]))*100
# Out:
# 2.3023791250959325

# %%
#Not Null 

(df.notnull().sum().sum()/(df.shape[0]*df.shape[1]))*100
# Out:
# 97.69762087490406

# %% [markdown]
# Percentage of Non-NUll Values

# %%
df.shape[0]*df.shape[1]
# Out:
# 15636

# %%
df.isna().sum().sum()
# Out:
# 360

# %%
df.describe()
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000

# %%
sns.heatmap(df.isna())
plt.savefig('null_values.png')
plt.show()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %% [markdown]
# Removing inches Column from the dataset in 'inplace'

# %%
df.drop(columns=['Inches'],inplace=True)

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  \
# 0            0.0   Apple           Ultrabook
# 1            1.0   Apple           Ultrabook
# 2            2.0      HP            Notebook
# 3            3.0   Apple           Ultrabook
# 4            4.0   Apple           Ultrabook
# ...          ...     ...                 ...
# 1298      1298.0  Lenovo  2 in 1 Convertible
# 1299      1299.0  Lenovo  2 in 1 Convertible
# 1300      1300.0  Lenovo            Notebook
# 1301      1301.0      HP            Notebook
# 1302      1302.0    Asus            Notebook
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df2=df.dropna()

# %%
df2
# Out:
#       Unnamed: 0 Company            TypeName  \
# 0            0.0   Apple           Ultrabook
# 1            1.0   Apple           Ultrabook
# 2            2.0      HP            Notebook
# 3            3.0   Apple           Ultrabook
# 4            4.0   Apple           Ultrabook
# ...          ...     ...                 ...
# 1298      1298.0  Lenovo  2 in 1 Convertible
# 1299      1299.0  Lenovo  2 in 1 Convertible
# 1300      1300.0  Lenovo            Notebook
# 1301      1301.0      HP            Notebook
# 1302      1302.0    Asus            Notebook
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df2.shape
# Out:
# (1273, 11)

# %%
df.shape
# Out:
# (1303, 11)

# %%
((df.shape[0]-df2.shape[0])/df.shape[0])*100
# Out:
# 2.3023791250959325

# %% [markdown]
# Filling the Mising Values in the Data

# %%
#Backward FIlling

# %%
df.fillna(method='ffill')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2516\1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#       Unnamed: 0 Company            TypeName  \
# 0            0.0   Apple           Ultrabook
# 1            1.0   Apple           Ultrabook
# 2            2.0      HP            Notebook
# 3            3.0   Apple           Ultrabook
# 4            4.0   Apple           Ultrabook
# ...          ...     ...                 ...
# 1298      1298.0  Lenovo  2 in 1 Convertible
# 1299      1299.0  Lenovo  2 in 1 Convertible
# 1300      1300.0  Lenovo            Notebook
# 1301      1301.0      HP            Notebook
# 1302      1302.0    Asus            Notebook
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# ...

# %%
#Forward FIlling

# %%
df.bfill()
# Out:
#       Unnamed: 0 Company            TypeName  \
# 0            0.0   Apple           Ultrabook
# 1            1.0   Apple           Ultrabook
# 2            2.0      HP            Notebook
# 3            3.0   Apple           Ultrabook
# 4            4.0   Apple           Ultrabook
# ...          ...     ...                 ...
# 1298      1298.0  Lenovo  2 in 1 Convertible
# 1299      1299.0  Lenovo  2 in 1 Convertible
# 1300      1300.0  Lenovo            Notebook
# 1301      1301.0      HP            Notebook
# 1302      1302.0    Asus            Notebook
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %% [markdown]
# Replacing values with the most repeating values

# %%
df['Memory'].mode()
# Out:
# 0    256GB SSD
# Name: Memory, dtype: object

# %%
df['Memory'].value_counts().sort_values(ascending=False)
# Out:
# Memory
# 256GB SSD                        401
# 1TB HDD                          217
# 500GB HDD                        130
# 512GB SSD                        116
# 128GB SSD +  1TB HDD              92
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              71
# 32GB Flash Storage                37
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 64GB Flash Storage                14
# 1TB SSD                           13
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          4
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 1TB SSD +  1TB HDD                 2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  500GB HDD             2
# 256GB SSD +  256GB SSD             2
# ...

# %%
df['Cpu'].fillna(df['Cpu'].mode()[0], inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2516\2875960820.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cpu'].fillna(df['Cpu'].mode()[0], inplace=True)

# %%
df_new=pd.read_csv('laptopData.csv')
df_new
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df_new.isna().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df_new['Cpu'].fillna(df_new['Cpu'].mode()[0], inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2516\2912520799.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new['Cpu'].fillna(df_new['Cpu'].mode()[0], inplace=True)

# %%
df_new.isna().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                  0
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df_new2=pd.read_csv('laptopData.csv')
df_new2
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df_new2.isna().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df_new2['Inches'].value_counts()
# Out:
# Inches
# 15.6    640
# 14      192
# 17.3    162
# 13.3    161
# 12.5     38
# 11.6     31
# 12        6
# 13.9      6
# 13.5      5
# 12.3      5
# 15.4      4
# 15        4
# 35.6      3
# 10.1      3
# 24        2
# 13        2
# 18.4      1
# 27.3      1
# 33.5      1
# ?         1
# 31.6      1
# 17        1
# 14.1      1
# 11.3      1
# 25.6      1
# Name: count, dtype: int64

# %%
df_new2['Inches'].isna().sum()
# Out:
# 30

# %%
df_new2['Inches']
# Out:
# 0       13.3
# 1       13.3
# 2       15.6
# 3       15.4
# 4       13.3
#         ...
# 1298      14
# 1299    13.3
# 1300      14
# 1301    15.6
# 1302    15.6
# Name: Inches, Length: 1303, dtype: object

# %%
df_new2.sample(10)
# Out:
#       Unnamed: 0 Company   TypeName Inches  \
# 10          10.0      HP   Notebook   15.6
# 711        711.0    Dell   Notebook     14
# 1189      1189.0    Acer     Gaming   17.3
# 543        543.0    Acer     Gaming   15.6
# 1238      1238.0     MSI     Gaming   15.6
# 116        116.0      HP   Notebook     14
# 534        534.0    Asus     Gaming   15.6
# 192        192.0  Xiaomi  Ultrabook   13.3
# 270        270.0   Apple  Ultrabook   13.3
# 63          63.0    Asus   Notebook     14
#
#                         ScreenResolution                          Cpu   Ram  \
# 10                              1366x768   Intel Core i5 7200U 2.5GHz   4GB
# 711                    Full HD 1920x1080  Intel Core i5 7440HQ 2.8GHz   8GB
# 1189         IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 543                    Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz   8GB
# 1238                   Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz   8GB
# ...

# %% [markdown]
# Handling Missing Values

# %%
df_new2['Inches'].fillna(df_new2['Inches'].mode()[0],inplace=True)

# %%
df_new2
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df=pd.read_csv('laptopData.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
sns.heatmap(df_new2.notna())
plt.show()

# %%
sns.heatmap(df_new2.isna())
plt.show()

# %%
df_new2.isna().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches               0
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df_new2['Company'].value_counts()
# Out:
# Company
# Lenovo       290
# Dell         287
# HP           266
# Asus         156
# Acer         103
# MSI           53
# Toshiba       47
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# LG             3
# Huawei         2
# Fujitsu        2
# Name: count, dtype: int64

# %%
company=df.groupby('Company')

# %%
df.groupby('Weight')['Company'].value_counts()
# Out:
# Weight    Company
# 0.0002kg  Dell       1
# 0.69kg    Lenovo     3
# 0.81kg    Samsung    2
# 0.91kg    Asus       1
# 0.920kg   Apple      4
#                     ..
# 7.2kg     Acer       1
#           Lenovo     1
# 8.23kg    Acer       1
# 8.4kg     Lenovo     1
# ?         Dell       1
# Name: count, Length: 357, dtype: int64

# %%
stat_memory=company['Memory'].value_counts()
stat_memory
# Out:
# Company  Memory
# Acer     1TB HDD               32
#          256GB SSD             27
#          500GB HDD             15
#          32GB Flash Storage    10
#          128GB SSD              7
#                                ..
# Toshiba  128GB SSD              9
#          500GB HDD              9
#          512GB SSD              8
# Vero     32GB Flash Storage     4
# Xiaomi   256GB SSD              4
# Name: count, Length: 129, dtype: int64

# %%
type(stat_memory)
# Out:
# pandas.core.series.Series

# %%
stat_memory.sort_values(ascending=False)
# Out:
# Company  Memory
# HP       256GB SSD                    107
# Dell     256GB SSD                    100
# Lenovo   256GB SSD                     90
# Dell     1TB HDD                       61
# Lenovo   1TB HDD                       48
#                                      ...
# Dell     16GB Flash Storage             1
# Lenovo   1.0TB HDD                      1
#          1TB HDD +  1TB HDD             1
#          256GB SSD +  1.0TB Hybrid      1
# Asus     16GB Flash Storage             1
# Name: count, Length: 129, dtype: int64

# %%
df_new2.sample(10)
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 436        436.0      HP            Notebook   15.6
# 362        362.0  Lenovo            Notebook   17.3
# 32          32.0      HP            Notebook   17.3
# 919        919.0     MSI              Gaming   15.6
# 260        260.0    Dell            Notebook   17.3
# 492        492.0    Asus              Gaming   15.6
# 1284      1284.0  Lenovo  2 in 1 Convertible     14
# 904        904.0  Lenovo            Notebook   15.6
# 1272      1272.0  Lenovo            Notebook     14
# 1218      1218.0  Lenovo              Gaming   15.6
#
#                                ScreenResolution  \
# 436                                    1366x768
# 362                                    1600x900
# 32                            Full HD 1920x1080
# 919                           Full HD 1920x1080
# 260                           Full HD 1920x1080
# 492                           Full HD 1920x1080
# ...

# %%
inc=df_new2.groupby('Inches')

# %%
inc_new=inc['Company'].value_counts()
inc_new
# Out:
# Inches  Company
# 10.1    Lenovo       3
# 11.3    Lenovo       1
# 11.6    Acer         9
#         HP           7
#         Asus         5
#                     ..
# 31.6    Dell         1
# 33.5    Microsoft    1
# 35.6    Lenovo       2
#         Asus         1
# ?       Dell         1
# Name: count, Length: 78, dtype: int64

# %%
df_new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1273 non-null   object
#  3   Inches            1303 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1273 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1273 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
for i in df_new2.select_dtypes(include='object'):
    df_new2[i].fillna(df_new2[i].mode()[0],inplace=True)

# %%
df_new2.isna().sum()
# Out:
# Unnamed: 0          30
# Company              0
# TypeName             0
# Inches               0
# ScreenResolution     0
# Cpu                  0
# Ram                  0
# Memory               0
# Gpu                  0
# OpSys                0
# Weight               0
# Price               30
# dtype: int64

# %%
for i in df_new2.select_dtypes(include='float64'):
    df_new2[i].fillna(df_new2[i].mode()[0],inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2516\229184825.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new2[i].fillna(df_new2[i].mode()[0],inplace=True)

# %%
df_new2
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df_new2.isna().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64
